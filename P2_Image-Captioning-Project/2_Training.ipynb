# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** I use the structure that introduced in course, word embedding , LSTM, linear then softmax. In the first try, I think it could need complex structure, so I use 3 stacked LSTM layers to train my model. This very slow and I did not see and overwhelming performace than 2 stacked layers. So I decided use 2 stacked LSTM layers as my basic struture and tuned other parameter to improve.
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** I used default transform train in traing, since it used in data preprocessing. It also provide some data augmentations and changing view of point by using random crop. But for the inferencing, it no need to cropping, so I resize image to 224 directly.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** I used embedding size is 256. This is very common embedding size for NLP, and it seems works well. I also had used 512 for my initl value for embedding size, but its performnace did not have overwhelming performance. So I decide use 256 as my final model.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** I still use Adam optimizer to train my model. This optimizer is pretty popluar now, and have better performance than others.

# %%
% load_ext autoreload
% autoreload 2

import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
import math

from model import EncoderCNN, DecoderRNN

## my hyper parameter
dropout = 0.5              # dropout
cv = 2                     # the max gradient value for clipping
layers = 2                 # number of LSTM layers
learning_rate = 0.001      # learning rate

## TODO #1: Select appropriate values for the Python variables below.
batch_size = 128           # batch size
vocab_threshold = 4        # minimum word count threshold
vocab_from_file = True     # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 10             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size, num_layers= layers, dropout=dropout)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 

criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters()) 

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=learning_rate)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=0.75s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|███████████████████████████████████████████████████████████████████████| 414113/414113 [00:33<00:00, 12282.36it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
% load_ext autoreload
% autoreload 2

import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()

for epoch in range(1, num_epochs+1):    
    for i_step in range(1, total_step+1):

        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
            
        # Backward pass.
        loss.backward()
        
        # Apply gradient clipping.
        torch.nn.utils.clip_grad_value_(decoder.parameters(), cv)
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)

    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Epoch [1/10], Step [100/3236], Loss: 4.2177, Perplexity: 67.87606
# Epoch [1/10], Step [200/3236], Loss: 4.1784, Perplexity: 65.25997
# Epoch [1/10], Step [300/3236], Loss: 3.8380, Perplexity: 46.43432
# Epoch [1/10], Step [400/3236], Loss: 3.4711, Perplexity: 32.1721
# Epoch [1/10], Step [500/3236], Loss: 3.5374, Perplexity: 34.3784
# Epoch [1/10], Step [600/3236], Loss: 3.4272, Perplexity: 30.7916
# Epoch [1/10], Step [700/3236], Loss: 3.1103, Perplexity: 22.4277
# Epoch [1/10], Step [800/3236], Loss: 3.0637, Perplexity: 21.4060
# Epoch [1/10], Step [900/3236], Loss: 2.9810, Perplexity: 19.7074
# Epoch [1/10], Step [1000/3236], Loss: 3.4164, Perplexity: 30.4598
# Epoch [1/10], Step [1100/3236], Loss: 3.3094, Perplexity: 27.3676
# Epoch [1/10], Step [1200/3236], Loss: 2.9735, Perplexity: 19.5593
# Epoch [1/10], Step [1300/3236], Loss: 2.8618, Perplexity: 17.4930
# Epoch [1/10], Step [1400/3236], Loss: 2.7616, Perplexity: 15.8255
# Epoch [1/10], Step [1500/3236], Loss: 2.7366, Perplexity: 15.4339
# Epoch [1/10], Step [1600/3236], Loss: 2.7055, Perplexity: 14.9620
# Epoch [1/10], Step [1700/3236], Loss: 2.9858, Perplexity: 19.8026
# Epoch [1/10], Step [1800/3236], Loss: 2.4149, Perplexity: 11.1891
# Epoch [1/10], Step [1900/3236], Loss: 2.5741, Perplexity: 13.1189
# Epoch [1/10], Step [2000/3236], Loss: 2.8525, Perplexity: 17.3311
# Epoch [1/10], Step [2100/3236], Loss: 2.5316, Perplexity: 12.5741
# Epoch [1/10], Step [2200/3236], Loss: 2.4411, Perplexity: 11.4860
# Epoch [1/10], Step [2300/3236], Loss: 2.5615, Perplexity: 12.9554
# Epoch [1/10], Step [2400/3236], Loss: 2.3294, Perplexity: 10.2717
# Epoch [1/10], Step [2500/3236], Loss: 2.4162, Perplexity: 11.2037
# Epoch [1/10], Step [2600/3236], Loss: 2.5804, Perplexity: 13.2018
# Epoch [1/10], Step [2700/3236], Loss: 2.2959, Perplexity: 9.93319
# Epoch [1/10], Step [2800/3236], Loss: 2.4429, Perplexity: 11.5058
# Epoch [1/10], Step [2900/3236], Loss: 2.3674, Perplexity: 10.6698
# Epoch [1/10], Step [3000/3236], Loss: 2.5407, Perplexity: 12.6883
# Epoch [1/10], Step [3100/3236], Loss: 2.2637, Perplexity: 9.61813
# Epoch [1/10], Step [3200/3236], Loss: 2.3170, Perplexity: 10.1453
# Epoch [2/10], Step [100/3236], Loss: 2.2629, Perplexity: 9.6112337
# Epoch [2/10], Step [200/3236], Loss: 2.3570, Perplexity: 10.5590
# Epoch [2/10], Step [300/3236], Loss: 2.4191, Perplexity: 11.2357
# Epoch [2/10], Step [400/3236], Loss: 2.2782, Perplexity: 9.75921
# Epoch [2/10], Step [500/3236], Loss: 2.2848, Perplexity: 9.82380
# Epoch [2/10], Step [600/3236], Loss: 2.2846, Perplexity: 9.82166
# Epoch [2/10], Step [700/3236], Loss: 2.3972, Perplexity: 10.9928
# Epoch [2/10], Step [800/3236], Loss: 2.1247, Perplexity: 8.37047
# Epoch [2/10], Step [900/3236], Loss: 2.2068, Perplexity: 9.08660
# Epoch [2/10], Step [1000/3236], Loss: 2.4836, Perplexity: 11.9848
# Epoch [2/10], Step [1100/3236], Loss: 2.1264, Perplexity: 8.38454
# Epoch [2/10], Step [1200/3236], Loss: 2.0945, Perplexity: 8.12100
# Epoch [2/10], Step [1300/3236], Loss: 2.2351, Perplexity: 9.347460
# Epoch [2/10], Step [1400/3236], Loss: 2.1476, Perplexity: 8.56407
# Epoch [2/10], Step [1500/3236], Loss: 2.4520, Perplexity: 11.6120
# Epoch [2/10], Step [1600/3236], Loss: 2.1876, Perplexity: 8.91386
# Epoch [2/10], Step [1700/3236], Loss: 2.0928, Perplexity: 8.10768
# Epoch [2/10], Step [1800/3236], Loss: 2.1144, Perplexity: 8.28482
# Epoch [2/10], Step [1900/3236], Loss: 2.1341, Perplexity: 8.44970
# Epoch [2/10], Step [2000/3236], Loss: 2.3102, Perplexity: 10.0761
# Epoch [2/10], Step [2100/3236], Loss: 2.0945, Perplexity: 8.12155
# Epoch [2/10], Step [2200/3236], Loss: 2.0734, Perplexity: 7.95222
# Epoch [2/10], Step [2300/3236], Loss: 2.2179, Perplexity: 9.18843
# Epoch [2/10], Step [2400/3236], Loss: 2.0749, Perplexity: 7.96375
# Epoch [2/10], Step [2500/3236], Loss: 2.1224, Perplexity: 8.35106
# Epoch [2/10], Step [2600/3236], Loss: 2.0226, Perplexity: 7.55823
# Epoch [2/10], Step [2700/3236], Loss: 2.1514, Perplexity: 8.59720
# Epoch [2/10], Step [2800/3236], Loss: 2.1648, Perplexity: 8.71297
# Epoch [2/10], Step [2900/3236], Loss: 2.1705, Perplexity: 8.76281
# Epoch [2/10], Step [3000/3236], Loss: 2.1318, Perplexity: 8.43019
# Epoch [2/10], Step [3100/3236], Loss: 2.0268, Perplexity: 7.58952
# Epoch [2/10], Step [3200/3236], Loss: 2.0122, Perplexity: 7.47960
# Epoch [3/10], Step [100/3236], Loss: 2.2782, Perplexity: 9.759197
# Epoch [3/10], Step [200/3236], Loss: 2.0217, Perplexity: 7.55080
# Epoch [3/10], Step [300/3236], Loss: 2.2601, Perplexity: 9.58423
# Epoch [3/10], Step [400/3236], Loss: 2.3849, Perplexity: 10.8582
# Epoch [3/10], Step [500/3236], Loss: 2.1385, Perplexity: 8.48685
# Epoch [3/10], Step [600/3236], Loss: 2.7504, Perplexity: 15.6492
# Epoch [3/10], Step [700/3236], Loss: 2.0764, Perplexity: 7.97611
# Epoch [3/10], Step [800/3236], Loss: 2.0942, Perplexity: 8.11894
# Epoch [3/10], Step [900/3236], Loss: 1.9008, Perplexity: 6.69119
# Epoch [3/10], Step [1000/3236], Loss: 2.2006, Perplexity: 9.0308
# Epoch [3/10], Step [1100/3236], Loss: 2.0056, Perplexity: 7.43095
# Epoch [3/10], Step [1200/3236], Loss: 2.7496, Perplexity: 15.6367
# Epoch [3/10], Step [1300/3236], Loss: 1.8878, Perplexity: 6.60453
# Epoch [3/10], Step [1400/3236], Loss: 2.0845, Perplexity: 8.04048
# Epoch [3/10], Step [1500/3236], Loss: 2.1114, Perplexity: 8.25968
# Epoch [3/10], Step [1600/3236], Loss: 1.9240, Perplexity: 6.84855
# Epoch [3/10], Step [1700/3236], Loss: 2.4241, Perplexity: 11.2917
# Epoch [3/10], Step [1800/3236], Loss: 1.9216, Perplexity: 6.83162
# Epoch [3/10], Step [1900/3236], Loss: 1.9468, Perplexity: 7.00648
# Epoch [3/10], Step [2000/3236], Loss: 2.0722, Perplexity: 7.94237
# Epoch [3/10], Step [2100/3236], Loss: 1.9171, Perplexity: 6.80132
# Epoch [3/10], Step [2200/3236], Loss: 2.0527, Perplexity: 7.78938
# Epoch [3/10], Step [2300/3236], Loss: 2.0722, Perplexity: 7.94278
# Epoch [3/10], Step [2400/3236], Loss: 2.0212, Perplexity: 7.54752
# Epoch [3/10], Step [2500/3236], Loss: 2.1017, Perplexity: 8.18013
# Epoch [3/10], Step [2600/3236], Loss: 2.0942, Perplexity: 8.11893
# Epoch [3/10], Step [2700/3236], Loss: 1.9332, Perplexity: 6.91154
# Epoch [3/10], Step [2800/3236], Loss: 1.9479, Perplexity: 7.01412
# Epoch [3/10], Step [2900/3236], Loss: 1.9459, Perplexity: 7.00018
# Epoch [3/10], Step [3000/3236], Loss: 2.3759, Perplexity: 10.7603
# Epoch [3/10], Step [3100/3236], Loss: 1.9810, Perplexity: 7.25024
# Epoch [3/10], Step [3200/3236], Loss: 1.9216, Perplexity: 6.83164
# Epoch [4/10], Step [100/3236], Loss: 2.0791, Perplexity: 7.997355
# Epoch [4/10], Step [200/3236], Loss: 2.2855, Perplexity: 9.83106
# Epoch [4/10], Step [300/3236], Loss: 1.8903, Perplexity: 6.62120
# Epoch [4/10], Step [400/3236], Loss: 2.0019, Perplexity: 7.40349
# Epoch [4/10], Step [500/3236], Loss: 1.8996, Perplexity: 6.68305
# Epoch [4/10], Step [600/3236], Loss: 2.1416, Perplexity: 8.51280
# Epoch [4/10], Step [700/3236], Loss: 1.9560, Perplexity: 7.07105
# Epoch [4/10], Step [800/3236], Loss: 2.0678, Perplexity: 7.90772
# Epoch [4/10], Step [900/3236], Loss: 2.2986, Perplexity: 9.96011
# Epoch [4/10], Step [1000/3236], Loss: 1.9618, Perplexity: 7.1124
# Epoch [4/10], Step [1100/3236], Loss: 2.0261, Perplexity: 7.58427
# Epoch [4/10], Step [1200/3236], Loss: 2.0150, Perplexity: 7.50045
# Epoch [4/10], Step [1300/3236], Loss: 2.0778, Perplexity: 7.98732
# Epoch [4/10], Step [1400/3236], Loss: 1.9315, Perplexity: 6.90012
# Epoch [4/10], Step [1500/3236], Loss: 1.8491, Perplexity: 6.35421
# Epoch [4/10], Step [1600/3236], Loss: 1.9324, Perplexity: 6.90590
# Epoch [4/10], Step [1700/3236], Loss: 1.9329, Perplexity: 6.90930
# Epoch [4/10], Step [1800/3236], Loss: 2.2661, Perplexity: 9.64129
# Epoch [4/10], Step [1900/3236], Loss: 1.9342, Perplexity: 6.91879
# Epoch [4/10], Step [2000/3236], Loss: 2.1261, Perplexity: 8.38227
# Epoch [4/10], Step [2100/3236], Loss: 1.9883, Perplexity: 7.30285
# Epoch [4/10], Step [2200/3236], Loss: 1.9511, Perplexity: 7.03611
# Epoch [4/10], Step [2300/3236], Loss: 1.8641, Perplexity: 6.45044
# Epoch [4/10], Step [2400/3236], Loss: 1.8369, Perplexity: 6.27707
# Epoch [4/10], Step [2500/3236], Loss: 1.9218, Perplexity: 6.83300
# Epoch [4/10], Step [2600/3236], Loss: 2.1076, Perplexity: 8.22825
# Epoch [4/10], Step [2700/3236], Loss: 2.3460, Perplexity: 10.4439
# Epoch [4/10], Step [2800/3236], Loss: 2.3450, Perplexity: 10.4334
# Epoch [4/10], Step [2900/3236], Loss: 2.1316, Perplexity: 8.42879
# Epoch [4/10], Step [3000/3236], Loss: 2.1110, Perplexity: 8.25689
# Epoch [4/10], Step [3100/3236], Loss: 2.1041, Perplexity: 8.19988
# Epoch [4/10], Step [3200/3236], Loss: 2.0438, Perplexity: 7.71968
# Epoch [5/10], Step [100/3236], Loss: 2.4468, Perplexity: 11.55159
# Epoch [5/10], Step [200/3236], Loss: 1.9708, Perplexity: 7.17659
# Epoch [5/10], Step [300/3236], Loss: 1.8590, Perplexity: 6.41720
# Epoch [5/10], Step [400/3236], Loss: 2.1057, Perplexity: 8.21302
# Epoch [5/10], Step [500/3236], Loss: 2.0308, Perplexity: 7.62023
# Epoch [5/10], Step [600/3236], Loss: 1.8857, Perplexity: 6.59070
# Epoch [5/10], Step [700/3236], Loss: 1.9473, Perplexity: 7.00951
# Epoch [5/10], Step [800/3236], Loss: 1.9874, Perplexity: 7.29676
# Epoch [5/10], Step [900/3236], Loss: 2.0256, Perplexity: 7.58068
# Epoch [5/10], Step [1000/3236], Loss: 2.2781, Perplexity: 9.7581
# Epoch [5/10], Step [1100/3236], Loss: 1.8643, Perplexity: 6.45150
# Epoch [5/10], Step [1200/3236], Loss: 2.4097, Perplexity: 11.1305
# Epoch [5/10], Step [1300/3236], Loss: 1.9192, Perplexity: 6.81543
# Epoch [5/10], Step [1400/3236], Loss: 1.8924, Perplexity: 6.63526
# Epoch [5/10], Step [1500/3236], Loss: 2.1578, Perplexity: 8.65209
# Epoch [5/10], Step [1600/3236], Loss: 1.9058, Perplexity: 6.72480
# Epoch [5/10], Step [1700/3236], Loss: 1.8956, Perplexity: 6.65639
# Epoch [5/10], Step [1800/3236], Loss: 1.8361, Perplexity: 6.27183
# Epoch [5/10], Step [1900/3236], Loss: 2.1535, Perplexity: 8.61484
# Epoch [5/10], Step [2000/3236], Loss: 1.9162, Perplexity: 6.79522
# Epoch [5/10], Step [2100/3236], Loss: 1.9631, Perplexity: 7.121127
# Epoch [5/10], Step [2200/3236], Loss: 2.6431, Perplexity: 14.0561
# Epoch [5/10], Step [2300/3236], Loss: 1.9133, Perplexity: 6.77537
# Epoch [5/10], Step [2400/3236], Loss: 1.9834, Perplexity: 7.26741
# Epoch [5/10], Step [2500/3236], Loss: 1.9090, Perplexity: 6.74624
# Epoch [5/10], Step [2600/3236], Loss: 2.0681, Perplexity: 7.90942
# Epoch [5/10], Step [2700/3236], Loss: 1.8823, Perplexity: 6.56878
# Epoch [5/10], Step [2800/3236], Loss: 2.3587, Perplexity: 10.5775
# Epoch [5/10], Step [2900/3236], Loss: 1.9230, Perplexity: 6.84131
# Epoch [5/10], Step [3000/3236], Loss: 2.2036, Perplexity: 9.05773
# Epoch [5/10], Step [3100/3236], Loss: 1.8186, Perplexity: 6.16320
# Epoch [5/10], Step [3200/3236], Loss: 1.7826, Perplexity: 5.94560
# Epoch [6/10], Step [100/3236], Loss: 1.8253, Perplexity: 6.204748
# Epoch [6/10], Step [200/3236], Loss: 2.2122, Perplexity: 9.13606
# Epoch [6/10], Step [300/3236], Loss: 1.8677, Perplexity: 6.47340
# Epoch [6/10], Step [400/3236], Loss: 2.0157, Perplexity: 7.50607
# Epoch [6/10], Step [500/3236], Loss: 2.0212, Perplexity: 7.54761
# Epoch [6/10], Step [600/3236], Loss: 3.3011, Perplexity: 27.1432
# Epoch [6/10], Step [700/3236], Loss: 2.0161, Perplexity: 7.50921
# Epoch [6/10], Step [800/3236], Loss: 1.8402, Perplexity: 6.29819
# Epoch [6/10], Step [900/3236], Loss: 2.1158, Perplexity: 8.29627
# Epoch [6/10], Step [1000/3236], Loss: 1.9507, Perplexity: 7.0339
# Epoch [6/10], Step [1100/3236], Loss: 1.8576, Perplexity: 6.40851
# Epoch [6/10], Step [1200/3236], Loss: 1.7993, Perplexity: 6.04574
# Epoch [6/10], Step [1300/3236], Loss: 1.9200, Perplexity: 6.82094
# Epoch [6/10], Step [1400/3236], Loss: 1.9983, Perplexity: 7.37655
# Epoch [6/10], Step [1500/3236], Loss: 1.8245, Perplexity: 6.19967
# Epoch [6/10], Step [1600/3236], Loss: 1.9399, Perplexity: 6.95805
# Epoch [6/10], Step [1700/3236], Loss: 1.8918, Perplexity: 6.63144
# Epoch [6/10], Step [1800/3236], Loss: 1.9130, Perplexity: 6.77352
# Epoch [6/10], Step [1900/3236], Loss: 1.9328, Perplexity: 6.90855
# Epoch [6/10], Step [2000/3236], Loss: 2.1997, Perplexity: 9.02276
# Epoch [6/10], Step [2100/3236], Loss: 1.8009, Perplexity: 6.05499
# Epoch [6/10], Step [2200/3236], Loss: 1.8328, Perplexity: 6.25115
# Epoch [6/10], Step [2300/3236], Loss: 2.1115, Perplexity: 8.26072
# Epoch [6/10], Step [2400/3236], Loss: 2.2107, Perplexity: 9.12217
# Epoch [6/10], Step [2500/3236], Loss: 1.9529, Perplexity: 7.04946
# Epoch [6/10], Step [2600/3236], Loss: 1.7174, Perplexity: 5.57017
# Epoch [6/10], Step [2700/3236], Loss: 1.8711, Perplexity: 6.49531
# Epoch [6/10], Step [2800/3236], Loss: 1.9479, Perplexity: 7.01391
# Epoch [6/10], Step [2900/3236], Loss: 1.8833, Perplexity: 6.57511
# Epoch [6/10], Step [3000/3236], Loss: 2.0823, Perplexity: 8.02290
# Epoch [6/10], Step [3100/3236], Loss: 1.7722, Perplexity: 5.88386
# Epoch [6/10], Step [3200/3236], Loss: 1.9742, Perplexity: 7.20103
# Epoch [7/10], Step [100/3236], Loss: 1.8911, Perplexity: 6.62655
# Epoch [7/10], Step [200/3236], Loss: 1.7550, Perplexity: 5.78339
# Epoch [7/10], Step [300/3236], Loss: 1.7407, Perplexity: 5.70110
# Epoch [7/10], Step [400/3236], Loss: 1.8765, Perplexity: 6.53098
# Epoch [7/10], Step [500/3236], Loss: 1.7607, Perplexity: 5.81626
# Epoch [7/10], Step [600/3236], Loss: 1.9108, Perplexity: 6.75884
# Epoch [7/10], Step [700/3236], Loss: 1.8523, Perplexity: 6.37427
# Epoch [7/10], Step [800/3236], Loss: 1.8680, Perplexity: 6.47532
# Epoch [7/10], Step [900/3236], Loss: 1.9184, Perplexity: 6.81034
# Epoch [7/10], Step [1000/3236], Loss: 2.2486, Perplexity: 9.4743
# Epoch [7/10], Step [1100/3236], Loss: 2.1559, Perplexity: 8.63577
# Epoch [7/10], Step [1200/3236], Loss: 1.9253, Perplexity: 6.85741
# Epoch [7/10], Step [1300/3236], Loss: 2.2256, Perplexity: 9.25948
# Epoch [7/10], Step [1400/3236], Loss: 1.8284, Perplexity: 6.22384
# Epoch [7/10], Step [1500/3236], Loss: 2.2863, Perplexity: 9.83889
# Epoch [7/10], Step [1600/3236], Loss: 2.0404, Perplexity: 7.69345
# Epoch [7/10], Step [1700/3236], Loss: 1.8472, Perplexity: 6.34224
# Epoch [7/10], Step [1800/3236], Loss: 1.8193, Perplexity: 6.16770
# Epoch [7/10], Step [1900/3236], Loss: 2.0162, Perplexity: 7.50995
# Epoch [7/10], Step [2000/3236], Loss: 1.8618, Perplexity: 6.43545
# Epoch [7/10], Step [2100/3236], Loss: 1.8664, Perplexity: 6.46489
# Epoch [7/10], Step [2200/3236], Loss: 1.8026, Perplexity: 6.06540
# Epoch [7/10], Step [2300/3236], Loss: 1.9725, Perplexity: 7.18880
# Epoch [7/10], Step [2400/3236], Loss: 1.7776, Perplexity: 5.91561
# Epoch [7/10], Step [2500/3236], Loss: 1.8097, Perplexity: 6.10879
# Epoch [7/10], Step [2600/3236], Loss: 1.7810, Perplexity: 5.93593
# Epoch [7/10], Step [2700/3236], Loss: 2.1233, Perplexity: 8.35844
# Epoch [7/10], Step [2800/3236], Loss: 1.8128, Perplexity: 6.12785
# Epoch [7/10], Step [2900/3236], Loss: 1.7915, Perplexity: 5.99840
# Epoch [7/10], Step [3000/3236], Loss: 1.7997, Perplexity: 6.04761
# Epoch [7/10], Step [3100/3236], Loss: 1.8050, Perplexity: 6.07989
# Epoch [7/10], Step [3200/3236], Loss: 1.8926, Perplexity: 6.63643
# Epoch [8/10], Step [100/3236], Loss: 1.8211, Perplexity: 6.178609
# Epoch [8/10], Step [200/3236], Loss: 2.4362, Perplexity: 11.4298
# Epoch [8/10], Step [300/3236], Loss: 1.7560, Perplexity: 5.78932
# Epoch [8/10], Step [400/3236], Loss: 1.8501, Perplexity: 6.36030
# Epoch [8/10], Step [500/3236], Loss: 1.7659, Perplexity: 5.84692
# Epoch [8/10], Step [600/3236], Loss: 1.8182, Perplexity: 6.16060
# Epoch [8/10], Step [700/3236], Loss: 1.8128, Perplexity: 6.12760
# Epoch [8/10], Step [800/3236], Loss: 1.8832, Perplexity: 6.57456
# Epoch [8/10], Step [900/3236], Loss: 1.8662, Perplexity: 6.46351
# Epoch [8/10], Step [1000/3236], Loss: 2.0727, Perplexity: 7.9466
# Epoch [8/10], Step [1100/3236], Loss: 1.7828, Perplexity: 5.94678
# Epoch [8/10], Step [1200/3236], Loss: 1.6556, Perplexity: 5.23621
# Epoch [8/10], Step [1300/3236], Loss: 1.8050, Perplexity: 6.07988
# Epoch [8/10], Step [1400/3236], Loss: 1.7638, Perplexity: 5.83431
# Epoch [8/10], Step [1500/3236], Loss: 1.8551, Perplexity: 6.39265
# Epoch [8/10], Step [1600/3236], Loss: 1.8714, Perplexity: 6.49774
# Epoch [8/10], Step [1700/3236], Loss: 1.7846, Perplexity: 5.95727
# Epoch [8/10], Step [1800/3236], Loss: 2.3852, Perplexity: 10.8612
# Epoch [8/10], Step [1900/3236], Loss: 1.8973, Perplexity: 6.66766
# Epoch [8/10], Step [2000/3236], Loss: 1.9252, Perplexity: 6.85632
# Epoch [8/10], Step [2100/3236], Loss: 2.7115, Perplexity: 15.0523
# Epoch [8/10], Step [2200/3236], Loss: 1.7823, Perplexity: 5.94321
# Epoch [8/10], Step [2300/3236], Loss: 2.2040, Perplexity: 9.06095
# Epoch [8/10], Step [2400/3236], Loss: 2.0688, Perplexity: 7.91570
# Epoch [8/10], Step [2500/3236], Loss: 2.1820, Perplexity: 8.86383
# Epoch [8/10], Step [2600/3236], Loss: 1.9139, Perplexity: 6.77974
# Epoch [8/10], Step [2700/3236], Loss: 1.9148, Perplexity: 6.78597
# Epoch [8/10], Step [2800/3236], Loss: 1.8181, Perplexity: 6.16044
# Epoch [8/10], Step [2900/3236], Loss: 1.8988, Perplexity: 6.67764
# Epoch [8/10], Step [3000/3236], Loss: 2.2526, Perplexity: 9.51242
# Epoch [8/10], Step [3100/3236], Loss: 1.7709, Perplexity: 5.87613
# Epoch [8/10], Step [3200/3236], Loss: 2.2176, Perplexity: 9.18507
# Epoch [9/10], Step [100/3236], Loss: 2.0887, Perplexity: 8.074298
# Epoch [9/10], Step [200/3236], Loss: 1.8717, Perplexity: 6.49916
# Epoch [9/10], Step [300/3236], Loss: 2.0340, Perplexity: 7.64452
# Epoch [9/10], Step [400/3236], Loss: 2.7912, Perplexity: 16.3006
# Epoch [9/10], Step [500/3236], Loss: 2.2908, Perplexity: 9.88301
# Epoch [9/10], Step [600/3236], Loss: 1.8785, Perplexity: 6.54380
# Epoch [9/10], Step [700/3236], Loss: 1.8855, Perplexity: 6.58980
# Epoch [9/10], Step [800/3236], Loss: 1.6468, Perplexity: 5.1901
# Epoch [9/10], Step [900/3236], Loss: 1.9561, Perplexity: 7.07202
# Epoch [9/10], Step [1000/3236], Loss: 1.8041, Perplexity: 6.0744
# Epoch [9/10], Step [1100/3236], Loss: 1.9222, Perplexity: 6.83607
# Epoch [9/10], Step [1200/3236], Loss: 1.7021, Perplexity: 5.48570
# Epoch [9/10], Step [1300/3236], Loss: 2.0359, Perplexity: 7.659398
# Epoch [9/10], Step [1400/3236], Loss: 1.8601, Perplexity: 6.42468
# Epoch [9/10], Step [1500/3236], Loss: 1.8792, Perplexity: 6.54855
# Epoch [9/10], Step [1600/3236], Loss: 1.7348, Perplexity: 5.66792
# Epoch [9/10], Step [1700/3236], Loss: 1.7775, Perplexity: 5.915085
# Epoch [9/10], Step [1800/3236], Loss: 2.1923, Perplexity: 8.95557
# Epoch [9/10], Step [1900/3236], Loss: 3.1643, Perplexity: 23.6732
# Epoch [9/10], Step [2000/3236], Loss: 2.0197, Perplexity: 7.53621
# Epoch [9/10], Step [2100/3236], Loss: 1.6704, Perplexity: 5.31419
# Epoch [9/10], Step [2200/3236], Loss: 1.9249, Perplexity: 6.85463
# Epoch [9/10], Step [2300/3236], Loss: 1.8027, Perplexity: 6.06618
# Epoch [9/10], Step [2400/3236], Loss: 1.8370, Perplexity: 6.27804
# Epoch [9/10], Step [2500/3236], Loss: 1.8360, Perplexity: 6.27154
# Epoch [9/10], Step [2600/3236], Loss: 2.0743, Perplexity: 7.95887
# Epoch [9/10], Step [2700/3236], Loss: 1.9702, Perplexity: 7.17209
# Epoch [9/10], Step [2800/3236], Loss: 1.8957, Perplexity: 6.65753
# Epoch [9/10], Step [2900/3236], Loss: 1.7707, Perplexity: 5.87495
# Epoch [9/10], Step [3000/3236], Loss: 1.8141, Perplexity: 6.13572
# Epoch [9/10], Step [3100/3236], Loss: 1.7500, Perplexity: 5.75452
# Epoch [9/10], Step [3200/3236], Loss: 1.8508, Perplexity: 6.36484
# Epoch [10/10], Step [100/3236], Loss: 1.8144, Perplexity: 6.13751
# Epoch [10/10], Step [200/3236], Loss: 1.8354, Perplexity: 6.26770
# Epoch [10/10], Step [300/3236], Loss: 1.9070, Perplexity: 6.73273
# Epoch [10/10], Step [400/3236], Loss: 1.7125, Perplexity: 5.54319
# Epoch [10/10], Step [500/3236], Loss: 1.7111, Perplexity: 5.53518
# Epoch [10/10], Step [600/3236], Loss: 2.0873, Perplexity: 8.06340
# Epoch [10/10], Step [700/3236], Loss: 1.6427, Perplexity: 5.16905
# Epoch [10/10], Step [800/3236], Loss: 1.7534, Perplexity: 5.77416
# Epoch [10/10], Step [900/3236], Loss: 1.8552, Perplexity: 6.39322
# Epoch [10/10], Step [1000/3236], Loss: 1.8627, Perplexity: 6.4413
# Epoch [10/10], Step [1100/3236], Loss: 1.9471, Perplexity: 7.00804
# Epoch [10/10], Step [1200/3236], Loss: 1.7777, Perplexity: 5.91610
# Epoch [10/10], Step [1300/3236], Loss: 1.7471, Perplexity: 5.73774
# Epoch [10/10], Step [1400/3236], Loss: 2.1090, Perplexity: 8.23986
# Epoch [10/10], Step [1500/3236], Loss: 1.6934, Perplexity: 5.43801
# Epoch [10/10], Step [1600/3236], Loss: 1.7755, Perplexity: 5.90328
# Epoch [10/10], Step [1700/3236], Loss: 1.7568, Perplexity: 5.79391
# Epoch [10/10], Step [1800/3236], Loss: 1.7490, Perplexity: 5.74902
# Epoch [10/10], Step [1900/3236], Loss: 1.9542, Perplexity: 7.05802
# Epoch [10/10], Step [2000/3236], Loss: 1.6756, Perplexity: 5.34215
# Epoch [10/10], Step [2100/3236], Loss: 1.8303, Perplexity: 6.23607
# Epoch [10/10], Step [2200/3236], Loss: 1.8317, Perplexity: 6.24430
# Epoch [10/10], Step [2300/3236], Loss: 1.8030, Perplexity: 6.06763
# Epoch [10/10], Step [2400/3236], Loss: 1.8504, Perplexity: 6.36226
# Epoch [10/10], Step [2500/3236], Loss: 1.9967, Perplexity: 7.36500
# Epoch [10/10], Step [2600/3236], Loss: 1.7606, Perplexity: 5.81616
# Epoch [10/10], Step [2700/3236], Loss: 1.7661, Perplexity: 5.84790
# Epoch [10/10], Step [2800/3236], Loss: 2.1452, Perplexity: 8.54416
# Epoch [10/10], Step [2900/3236], Loss: 1.9057, Perplexity: 6.72402
# Epoch [10/10], Step [3000/3236], Loss: 1.7523, Perplexity: 5.76818
# Epoch [10/10], Step [3100/3236], Loss: 2.0353, Perplexity: 7.65477
# Epoch [10/10], Step [3200/3236], Loss: 1.9402, Perplexity: 6.96039
# Epoch [10/10], Step [3236/3236], Loss: 1.9723, Perplexity: 7.1871

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.

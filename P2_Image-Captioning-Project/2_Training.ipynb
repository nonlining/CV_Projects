# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**

# %%
% load_ext autoreload
% autoreload 2

import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
import math

from model import EncoderCNN, DecoderRNN

dropout = 0.5              # dropout
cv = 2                     # the maxgradient value for clipping
layers = 2                 # number of LSTM layers
learning_rate = 0.001

## TODO #1: Select appropriate values for the Python variables below.
batch_size = 128           # batch size
vocab_threshold = 4        # minimum word count threshold
vocab_from_file = True     # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 10             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size, num_layers= layers, dropout=dropout)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 

criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters()) 

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=learning_rate)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=0.84s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|███████████████████████████████████████████████████████████████████████| 414113/414113 [00:33<00:00, 12529.73it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
% load_ext autoreload
% autoreload 2

import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()

for epoch in range(1, num_epochs+1):    
    for i_step in range(1, total_step+1):

        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
            
        # Backward pass.
        loss.backward()
        
        # Apply gradient clipping.
        torch.nn.utils.clip_grad_value_(decoder.parameters(), cv)
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)

    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Epoch [1/10], Step [100/3236], Loss: 4.2633, Perplexity: 71.04520
# Epoch [1/10], Step [200/3236], Loss: 3.7429, Perplexity: 42.22070
# Epoch [1/10], Step [300/3236], Loss: 3.4422, Perplexity: 31.25723
# Epoch [1/10], Step [400/3236], Loss: 3.8838, Perplexity: 48.60659
# Epoch [1/10], Step [500/3236], Loss: 3.1216, Perplexity: 22.6817
# Epoch [1/10], Step [600/3236], Loss: 5.6825, Perplexity: 293.6838
# Epoch [1/10], Step [700/3236], Loss: 2.9827, Perplexity: 19.74167
# Epoch [1/10], Step [800/3236], Loss: 2.8616, Perplexity: 17.4894
# Epoch [1/10], Step [900/3236], Loss: 3.0746, Perplexity: 21.6402
# Epoch [1/10], Step [1000/3236], Loss: 2.9344, Perplexity: 18.8110
# Epoch [1/10], Step [1100/3236], Loss: 2.7874, Perplexity: 16.2395
# Epoch [1/10], Step [1200/3236], Loss: 2.9368, Perplexity: 18.85501
# Epoch [1/10], Step [1300/3236], Loss: 2.5712, Perplexity: 13.0810
# Epoch [1/10], Step [1400/3236], Loss: 2.4851, Perplexity: 12.00283
# Epoch [1/10], Step [1500/3236], Loss: 2.7274, Perplexity: 15.2934
# Epoch [1/10], Step [1600/3236], Loss: 2.6240, Perplexity: 13.7901
# Epoch [1/10], Step [1700/3236], Loss: 2.9911, Perplexity: 19.9072
# Epoch [1/10], Step [1800/3236], Loss: 2.4968, Perplexity: 12.1431
# Epoch [1/10], Step [1900/3236], Loss: 2.5332, Perplexity: 12.5933
# Epoch [1/10], Step [2000/3236], Loss: 2.6232, Perplexity: 13.7796
# Epoch [1/10], Step [2100/3236], Loss: 2.3530, Perplexity: 10.51696
# Epoch [1/10], Step [2200/3236], Loss: 2.3321, Perplexity: 10.2999
# Epoch [1/10], Step [2300/3236], Loss: 2.3524, Perplexity: 10.5113
# Epoch [1/10], Step [2400/3236], Loss: 2.3690, Perplexity: 10.68709
# Epoch [1/10], Step [2500/3236], Loss: 2.7686, Perplexity: 15.9364
# Epoch [1/10], Step [2600/3236], Loss: 2.1913, Perplexity: 8.94689
# Epoch [1/10], Step [2700/3236], Loss: 2.2864, Perplexity: 9.83980
# Epoch [1/10], Step [2800/3236], Loss: 2.1387, Perplexity: 8.48824
# Epoch [1/10], Step [2900/3236], Loss: 2.1525, Perplexity: 8.60653
# Epoch [1/10], Step [3000/3236], Loss: 2.3539, Perplexity: 10.5269
# Epoch [1/10], Step [3100/3236], Loss: 2.4751, Perplexity: 11.8831
# Epoch [1/10], Step [3200/3236], Loss: 2.3115, Perplexity: 10.0894
# Epoch [2/10], Step [100/3236], Loss: 2.4351, Perplexity: 11.41695
# Epoch [2/10], Step [200/3236], Loss: 2.0467, Perplexity: 7.74224
# Epoch [2/10], Step [300/3236], Loss: 2.2390, Perplexity: 9.38414
# Epoch [2/10], Step [400/3236], Loss: 2.1252, Perplexity: 8.37459
# Epoch [2/10], Step [500/3236], Loss: 2.3315, Perplexity: 10.2936
# Epoch [2/10], Step [600/3236], Loss: 2.3733, Perplexity: 10.7329
# Epoch [2/10], Step [700/3236], Loss: 2.2144, Perplexity: 9.15606
# Epoch [2/10], Step [800/3236], Loss: 2.0522, Perplexity: 7.78476
# Epoch [2/10], Step [900/3236], Loss: 2.1835, Perplexity: 8.87763
# Epoch [2/10], Step [1000/3236], Loss: 2.1093, Perplexity: 8.2424
# Epoch [2/10], Step [1100/3236], Loss: 2.1768, Perplexity: 8.81774
# Epoch [2/10], Step [1200/3236], Loss: 2.1141, Perplexity: 8.28210
# Epoch [2/10], Step [1300/3236], Loss: 2.3681, Perplexity: 10.6769
# Epoch [2/10], Step [1400/3236], Loss: 2.4428, Perplexity: 11.5048
# Epoch [2/10], Step [1500/3236], Loss: 2.2425, Perplexity: 9.41684
# Epoch [2/10], Step [1600/3236], Loss: 2.0639, Perplexity: 7.87686
# Epoch [2/10], Step [1700/3236], Loss: 2.3875, Perplexity: 10.8867
# Epoch [2/10], Step [1800/3236], Loss: 2.0864, Perplexity: 8.05557
# Epoch [2/10], Step [1900/3236], Loss: 2.2326, Perplexity: 9.32450
# Epoch [2/10], Step [2000/3236], Loss: 2.5940, Perplexity: 13.3838
# Epoch [2/10], Step [2100/3236], Loss: 2.0876, Perplexity: 8.06560
# Epoch [2/10], Step [2200/3236], Loss: 2.3826, Perplexity: 10.8334
# Epoch [2/10], Step [2300/3236], Loss: 2.1207, Perplexity: 8.33661
# Epoch [2/10], Step [2400/3236], Loss: 2.6737, Perplexity: 14.4939
# Epoch [2/10], Step [2500/3236], Loss: 2.1683, Perplexity: 8.74326
# Epoch [2/10], Step [2600/3236], Loss: 2.1082, Perplexity: 8.23386
# Epoch [2/10], Step [2700/3236], Loss: 2.2079, Perplexity: 9.09623
# Epoch [2/10], Step [2800/3236], Loss: 2.0178, Perplexity: 7.52166
# Epoch [2/10], Step [2900/3236], Loss: 2.1750, Perplexity: 8.80225
# Epoch [2/10], Step [3000/3236], Loss: 2.9588, Perplexity: 19.2745
# Epoch [2/10], Step [3100/3236], Loss: 2.6883, Perplexity: 14.7059
# Epoch [2/10], Step [3200/3236], Loss: 2.1525, Perplexity: 8.60670
# Epoch [3/10], Step [100/3236], Loss: 2.2489, Perplexity: 9.477844
# Epoch [3/10], Step [200/3236], Loss: 2.1099, Perplexity: 8.24726
# Epoch [3/10], Step [300/3236], Loss: 2.1177, Perplexity: 8.31205
# Epoch [3/10], Step [400/3236], Loss: 1.9964, Perplexity: 7.36276
# Epoch [3/10], Step [500/3236], Loss: 2.0766, Perplexity: 7.97731
# Epoch [3/10], Step [600/3236], Loss: 1.9249, Perplexity: 6.85418
# Epoch [3/10], Step [700/3236], Loss: 2.0872, Perplexity: 8.06244
# Epoch [3/10], Step [800/3236], Loss: 2.3095, Perplexity: 10.0692
# Epoch [3/10], Step [900/3236], Loss: 2.0857, Perplexity: 8.04997
# Epoch [3/10], Step [1000/3236], Loss: 1.8476, Perplexity: 6.3446
# Epoch [3/10], Step [1100/3236], Loss: 2.0948, Perplexity: 8.12371
# Epoch [3/10], Step [1200/3236], Loss: 2.1060, Perplexity: 8.21551
# Epoch [3/10], Step [1300/3236], Loss: 1.9926, Perplexity: 7.33451
# Epoch [3/10], Step [1400/3236], Loss: 2.6739, Perplexity: 14.4959
# Epoch [3/10], Step [1500/3236], Loss: 2.0818, Perplexity: 8.01866
# Epoch [3/10], Step [1600/3236], Loss: 1.9785, Perplexity: 7.23157
# Epoch [3/10], Step [1700/3236], Loss: 1.9752, Perplexity: 7.20830
# Epoch [3/10], Step [1800/3236], Loss: 1.9979, Perplexity: 7.37372
# Epoch [3/10], Step [1900/3236], Loss: 2.1890, Perplexity: 8.92645
# Epoch [3/10], Step [2000/3236], Loss: 2.2914, Perplexity: 9.88902
# Epoch [3/10], Step [2100/3236], Loss: 2.1395, Perplexity: 8.49495
# Epoch [3/10], Step [2200/3236], Loss: 2.1714, Perplexity: 8.77090
# Epoch [3/10], Step [2300/3236], Loss: 2.1135, Perplexity: 8.27697
# Epoch [3/10], Step [2400/3236], Loss: 1.8410, Perplexity: 6.30294
# Epoch [3/10], Step [2500/3236], Loss: 2.0492, Perplexity: 7.76196
# Epoch [3/10], Step [2600/3236], Loss: 2.0428, Perplexity: 7.71197
# Epoch [3/10], Step [2700/3236], Loss: 2.0409, Perplexity: 7.69794
# Epoch [3/10], Step [2800/3236], Loss: 2.1820, Perplexity: 8.86457
# Epoch [3/10], Step [2900/3236], Loss: 2.0001, Perplexity: 7.38985
# Epoch [3/10], Step [3000/3236], Loss: 1.9936, Perplexity: 7.34174
# Epoch [3/10], Step [3100/3236], Loss: 1.9374, Perplexity: 6.94057
# Epoch [3/10], Step [3200/3236], Loss: 2.0806, Perplexity: 8.00958
# Epoch [4/10], Step [100/3236], Loss: 1.9509, Perplexity: 7.035322
# Epoch [4/10], Step [200/3236], Loss: 2.0726, Perplexity: 7.94555
# Epoch [4/10], Step [300/3236], Loss: 1.9607, Perplexity: 7.10465
# Epoch [4/10], Step [400/3236], Loss: 2.0424, Perplexity: 7.70926
# Epoch [4/10], Step [500/3236], Loss: 1.9572, Perplexity: 7.07963
# Epoch [4/10], Step [600/3236], Loss: 2.4812, Perplexity: 11.95589
# Epoch [4/10], Step [700/3236], Loss: 2.5981, Perplexity: 13.4388
# Epoch [4/10], Step [800/3236], Loss: 1.9548, Perplexity: 7.06223
# Epoch [4/10], Step [900/3236], Loss: 2.0366, Perplexity: 7.66470
# Epoch [4/10], Step [1000/3236], Loss: 1.8925, Perplexity: 6.6359
# Epoch [4/10], Step [1100/3236], Loss: 1.9993, Perplexity: 7.38386
# Epoch [4/10], Step [1200/3236], Loss: 2.0390, Perplexity: 7.68283
# Epoch [4/10], Step [1300/3236], Loss: 2.7176, Perplexity: 15.1435
# Epoch [4/10], Step [1400/3236], Loss: 2.1431, Perplexity: 8.52572
# Epoch [4/10], Step [1500/3236], Loss: 2.8096, Perplexity: 16.6025
# Epoch [4/10], Step [1600/3236], Loss: 1.8495, Perplexity: 6.35671
# Epoch [4/10], Step [1700/3236], Loss: 1.9128, Perplexity: 6.77220
# Epoch [4/10], Step [1800/3236], Loss: 1.9022, Perplexity: 6.70096
# Epoch [4/10], Step [1900/3236], Loss: 1.9250, Perplexity: 6.85524
# Epoch [4/10], Step [2000/3236], Loss: 1.9216, Perplexity: 6.83197
# Epoch [4/10], Step [2100/3236], Loss: 1.9932, Perplexity: 7.33922
# Epoch [4/10], Step [2200/3236], Loss: 2.2186, Perplexity: 9.19484
# Epoch [4/10], Step [2300/3236], Loss: 1.9187, Perplexity: 6.81181
# Epoch [4/10], Step [2400/3236], Loss: 1.9437, Perplexity: 6.98430
# Epoch [4/10], Step [2500/3236], Loss: 1.7932, Perplexity: 6.00872
# Epoch [4/10], Step [2600/3236], Loss: 1.8533, Perplexity: 6.38091
# Epoch [4/10], Step [2700/3236], Loss: 2.4262, Perplexity: 11.3158
# Epoch [4/10], Step [2800/3236], Loss: 2.0048, Perplexity: 7.42447
# Epoch [4/10], Step [2900/3236], Loss: 1.8203, Perplexity: 6.17386
# Epoch [4/10], Step [3000/3236], Loss: 1.9515, Perplexity: 7.03895
# Epoch [4/10], Step [3100/3236], Loss: 2.1580, Perplexity: 8.65423
# Epoch [4/10], Step [3200/3236], Loss: 1.9344, Perplexity: 6.91986
# Epoch [5/10], Step [100/3236], Loss: 1.9040, Perplexity: 6.712632
# Epoch [5/10], Step [200/3236], Loss: 1.9181, Perplexity: 6.80809
# Epoch [5/10], Step [300/3236], Loss: 1.9249, Perplexity: 6.85459
# Epoch [5/10], Step [400/3236], Loss: 1.9482, Perplexity: 7.01633
# Epoch [5/10], Step [500/3236], Loss: 1.8792, Perplexity: 6.54819
# Epoch [5/10], Step [600/3236], Loss: 1.8925, Perplexity: 6.63606
# Epoch [5/10], Step [700/3236], Loss: 1.8982, Perplexity: 6.67384
# Epoch [5/10], Step [800/3236], Loss: 1.8462, Perplexity: 6.33583
# Epoch [5/10], Step [900/3236], Loss: 1.7924, Perplexity: 6.00376
# Epoch [5/10], Step [1000/3236], Loss: 2.0602, Perplexity: 7.8474
# Epoch [5/10], Step [1100/3236], Loss: 1.8723, Perplexity: 6.50342
# Epoch [5/10], Step [1200/3236], Loss: 1.8070, Perplexity: 6.09191
# Epoch [5/10], Step [1300/3236], Loss: 2.1114, Perplexity: 8.25963
# Epoch [5/10], Step [1400/3236], Loss: 2.2424, Perplexity: 9.41582
# Epoch [5/10], Step [1500/3236], Loss: 1.8243, Perplexity: 6.19826
# Epoch [5/10], Step [1600/3236], Loss: 2.0214, Perplexity: 7.54899
# Epoch [5/10], Step [1700/3236], Loss: 2.2200, Perplexity: 9.20743
# Epoch [5/10], Step [1800/3236], Loss: 1.8777, Perplexity: 6.53842
# Epoch [5/10], Step [1900/3236], Loss: 1.8381, Perplexity: 6.28484
# Epoch [5/10], Step [2000/3236], Loss: 1.7474, Perplexity: 5.73988
# Epoch [5/10], Step [2100/3236], Loss: 1.9456, Perplexity: 6.99783
# Epoch [5/10], Step [2200/3236], Loss: 2.7553, Perplexity: 15.7265
# Epoch [5/10], Step [2300/3236], Loss: 1.9211, Perplexity: 6.82826
# Epoch [5/10], Step [2400/3236], Loss: 1.7850, Perplexity: 5.95976
# Epoch [5/10], Step [2500/3236], Loss: 1.9141, Perplexity: 6.78064
# Epoch [5/10], Step [2600/3236], Loss: 1.8579, Perplexity: 6.41020
# Epoch [5/10], Step [2700/3236], Loss: 2.3917, Perplexity: 10.9318
# Epoch [5/10], Step [2800/3236], Loss: 1.9375, Perplexity: 6.94115
# Epoch [5/10], Step [2900/3236], Loss: 1.8800, Perplexity: 6.55336
# Epoch [5/10], Step [3000/3236], Loss: 2.0143, Perplexity: 7.49545
# Epoch [5/10], Step [3100/3236], Loss: 1.8887, Perplexity: 6.61067
# Epoch [5/10], Step [3200/3236], Loss: 1.9358, Perplexity: 6.92931
# Epoch [6/10], Step [100/3236], Loss: 1.8946, Perplexity: 6.649999
# Epoch [6/10], Step [200/3236], Loss: 1.8017, Perplexity: 6.05988
# Epoch [6/10], Step [300/3236], Loss: 1.9618, Perplexity: 7.11185
# Epoch [6/10], Step [400/3236], Loss: 1.9304, Perplexity: 6.89250
# Epoch [6/10], Step [500/3236], Loss: 1.7794, Perplexity: 5.92611
# Epoch [6/10], Step [600/3236], Loss: 1.8199, Perplexity: 6.17124
# Epoch [6/10], Step [700/3236], Loss: 1.7651, Perplexity: 5.84200
# Epoch [6/10], Step [800/3236], Loss: 1.9088, Perplexity: 6.74507
# Epoch [6/10], Step [900/3236], Loss: 1.7260, Perplexity: 5.61796
# Epoch [6/10], Step [1000/3236], Loss: 2.3273, Perplexity: 10.2497
# Epoch [6/10], Step [1100/3236], Loss: 1.8793, Perplexity: 6.54893
# Epoch [6/10], Step [1200/3236], Loss: 1.9042, Perplexity: 6.71435
# Epoch [6/10], Step [1300/3236], Loss: 1.7841, Perplexity: 5.95422
# Epoch [6/10], Step [1400/3236], Loss: 1.9883, Perplexity: 7.30336
# Epoch [6/10], Step [1500/3236], Loss: 1.9446, Perplexity: 6.99109
# Epoch [6/10], Step [1600/3236], Loss: 2.0876, Perplexity: 8.06536
# Epoch [6/10], Step [1700/3236], Loss: 2.7138, Perplexity: 15.0867
# Epoch [6/10], Step [1800/3236], Loss: 1.7493, Perplexity: 5.75059
# Epoch [6/10], Step [1900/3236], Loss: 1.9487, Perplexity: 7.01966
# Epoch [6/10], Step [2000/3236], Loss: 1.9466, Perplexity: 7.00495
# Epoch [6/10], Step [2100/3236], Loss: 1.6793, Perplexity: 5.36182
# Epoch [6/10], Step [2200/3236], Loss: 1.8761, Perplexity: 6.52796
# Epoch [6/10], Step [2300/3236], Loss: 2.0408, Perplexity: 7.69716
# Epoch [6/10], Step [2400/3236], Loss: 2.1336, Perplexity: 8.44490
# Epoch [6/10], Step [2500/3236], Loss: 2.0671, Perplexity: 7.90174
# Epoch [6/10], Step [2600/3236], Loss: 1.7883, Perplexity: 5.97934
# Epoch [6/10], Step [2700/3236], Loss: 1.9936, Perplexity: 7.34168
# Epoch [6/10], Step [2800/3236], Loss: 1.8339, Perplexity: 6.25857
# Epoch [6/10], Step [2900/3236], Loss: 1.9260, Perplexity: 6.86212
# Epoch [6/10], Step [3000/3236], Loss: 1.8285, Perplexity: 6.22485
# Epoch [6/10], Step [3100/3236], Loss: 1.8578, Perplexity: 6.40981
# Epoch [6/10], Step [3200/3236], Loss: 1.8041, Perplexity: 6.07437
# Epoch [7/10], Step [100/3236], Loss: 1.8902, Perplexity: 6.620850
# Epoch [7/10], Step [200/3236], Loss: 1.9863, Perplexity: 7.28852
# Epoch [7/10], Step [300/3236], Loss: 1.8445, Perplexity: 6.32470
# Epoch [7/10], Step [400/3236], Loss: 1.9291, Perplexity: 6.88324
# Epoch [7/10], Step [500/3236], Loss: 1.9278, Perplexity: 6.87428
# Epoch [7/10], Step [600/3236], Loss: 1.9489, Perplexity: 7.02111
# Epoch [7/10], Step [700/3236], Loss: 1.8914, Perplexity: 6.62888
# Epoch [7/10], Step [800/3236], Loss: 2.0258, Perplexity: 7.58223
# Epoch [7/10], Step [900/3236], Loss: 1.7188, Perplexity: 5.57816
# Epoch [7/10], Step [1000/3236], Loss: 1.7883, Perplexity: 5.9794
# Epoch [7/10], Step [1100/3236], Loss: 2.0086, Perplexity: 7.45287
# Epoch [7/10], Step [1200/3236], Loss: 1.8978, Perplexity: 6.67133
# Epoch [7/10], Step [1300/3236], Loss: 2.0442, Perplexity: 7.72281
# Epoch [7/10], Step [1400/3236], Loss: 1.8858, Perplexity: 6.59150
# Epoch [7/10], Step [1500/3236], Loss: 2.0771, Perplexity: 7.98156
# Epoch [7/10], Step [1600/3236], Loss: 1.8318, Perplexity: 6.24508
# Epoch [7/10], Step [1700/3236], Loss: 1.8351, Perplexity: 6.26551
# Epoch [7/10], Step [1800/3236], Loss: 1.8914, Perplexity: 6.62873
# Epoch [7/10], Step [1900/3236], Loss: 1.9647, Perplexity: 7.13311
# Epoch [7/10], Step [2000/3236], Loss: 1.8355, Perplexity: 6.26852
# Epoch [7/10], Step [2100/3236], Loss: 1.8508, Perplexity: 6.36496
# Epoch [7/10], Step [2200/3236], Loss: 2.5216, Perplexity: 12.4479
# Epoch [7/10], Step [2300/3236], Loss: 1.9325, Perplexity: 6.90703
# Epoch [7/10], Step [2400/3236], Loss: 1.9752, Perplexity: 7.20820
# Epoch [7/10], Step [2500/3236], Loss: 1.8766, Perplexity: 6.53118
# Epoch [7/10], Step [2600/3236], Loss: 1.8145, Perplexity: 6.13825
# Epoch [7/10], Step [2700/3236], Loss: 1.7414, Perplexity: 5.70561
# Epoch [7/10], Step [2800/3236], Loss: 1.8026, Perplexity: 6.06537
# Epoch [7/10], Step [2900/3236], Loss: 1.7456, Perplexity: 5.72931
# Epoch [7/10], Step [3000/3236], Loss: 1.9893, Perplexity: 7.31055
# Epoch [7/10], Step [3100/3236], Loss: 1.7891, Perplexity: 5.98414
# Epoch [7/10], Step [3200/3236], Loss: 2.0010, Perplexity: 7.39630
# Epoch [8/10], Step [100/3236], Loss: 1.8302, Perplexity: 6.23524
# Epoch [8/10], Step [200/3236], Loss: 1.8090, Perplexity: 6.10440
# Epoch [8/10], Step [300/3236], Loss: 1.8056, Perplexity: 6.08335
# Epoch [8/10], Step [400/3236], Loss: 1.7606, Perplexity: 5.81591
# Epoch [8/10], Step [500/3236], Loss: 2.0682, Perplexity: 7.91039
# Epoch [8/10], Step [600/3236], Loss: 1.8153, Perplexity: 6.14322
# Epoch [8/10], Step [700/3236], Loss: 1.8067, Perplexity: 6.09008
# Epoch [8/10], Step [800/3236], Loss: 1.8049, Perplexity: 6.07932
# Epoch [8/10], Step [900/3236], Loss: 1.9045, Perplexity: 6.71600
# Epoch [8/10], Step [1000/3236], Loss: 1.9084, Perplexity: 6.7426
# Epoch [8/10], Step [1100/3236], Loss: 1.8319, Perplexity: 6.24582
# Epoch [8/10], Step [1200/3236], Loss: 1.8537, Perplexity: 6.38350
# Epoch [8/10], Step [1300/3236], Loss: 1.7980, Perplexity: 6.03775
# Epoch [8/10], Step [1400/3236], Loss: 1.7797, Perplexity: 5.9282
# Epoch [8/10], Step [1500/3236], Loss: 1.8185, Perplexity: 6.16251
# Epoch [8/10], Step [1600/3236], Loss: 1.7216, Perplexity: 5.593634
# Epoch [8/10], Step [1700/3236], Loss: 1.9294, Perplexity: 6.885758
# Epoch [8/10], Step [1800/3236], Loss: 1.8647, Perplexity: 6.45401
# Epoch [8/10], Step [1900/3236], Loss: 1.9865, Perplexity: 7.29015
# Epoch [8/10], Step [2000/3236], Loss: 1.8186, Perplexity: 6.16357
# Epoch [8/10], Step [2100/3236], Loss: 2.0614, Perplexity: 7.85678
# Epoch [8/10], Step [2200/3236], Loss: 2.0066, Perplexity: 7.43786
# Epoch [8/10], Step [2300/3236], Loss: 1.8340, Perplexity: 6.25862
# Epoch [8/10], Step [2400/3236], Loss: 1.7895, Perplexity: 5.98644
# Epoch [8/10], Step [2500/3236], Loss: 1.7937, Perplexity: 6.01154
# Epoch [8/10], Step [2600/3236], Loss: 1.9304, Perplexity: 6.89249
# Epoch [8/10], Step [2700/3236], Loss: 1.7949, Perplexity: 6.01892
# Epoch [8/10], Step [2800/3236], Loss: 1.8790, Perplexity: 6.54720
# Epoch [8/10], Step [2900/3236], Loss: 1.8039, Perplexity: 6.07337
# Epoch [8/10], Step [3000/3236], Loss: 1.8081, Perplexity: 6.09919
# Epoch [8/10], Step [3100/3236], Loss: 2.2338, Perplexity: 9.33560
# Epoch [8/10], Step [3200/3236], Loss: 1.8665, Perplexity: 6.46556
# Epoch [9/10], Step [100/3236], Loss: 2.1138, Perplexity: 8.279882
# Epoch [9/10], Step [200/3236], Loss: 1.8089, Perplexity: 6.10358
# Epoch [9/10], Step [300/3236], Loss: 1.7976, Perplexity: 6.03545
# Epoch [9/10], Step [400/3236], Loss: 1.7040, Perplexity: 5.49628
# Epoch [9/10], Step [500/3236], Loss: 1.8918, Perplexity: 6.63164
# Epoch [9/10], Step [600/3236], Loss: 1.8196, Perplexity: 6.16934
# Epoch [9/10], Step [700/3236], Loss: 1.8321, Perplexity: 6.24695
# Epoch [9/10], Step [800/3236], Loss: 1.8792, Perplexity: 6.54819
# Epoch [9/10], Step [900/3236], Loss: 1.8496, Perplexity: 6.35736
# Epoch [9/10], Step [1000/3236], Loss: 2.3937, Perplexity: 10.9535
# Epoch [9/10], Step [1100/3236], Loss: 1.8364, Perplexity: 6.27406
# Epoch [9/10], Step [1200/3236], Loss: 2.0269, Perplexity: 7.59038
# Epoch [9/10], Step [1300/3236], Loss: 1.8444, Perplexity: 6.32441
# Epoch [9/10], Step [1400/3236], Loss: 1.7610, Perplexity: 5.81805
# Epoch [9/10], Step [1500/3236], Loss: 1.9298, Perplexity: 6.88834
# Epoch [9/10], Step [1600/3236], Loss: 2.1500, Perplexity: 8.58485
# Epoch [9/10], Step [1700/3236], Loss: 1.7930, Perplexity: 6.00759
# Epoch [9/10], Step [1800/3236], Loss: 2.0320, Perplexity: 7.62943
# Epoch [9/10], Step [1900/3236], Loss: 1.6974, Perplexity: 5.45965
# Epoch [9/10], Step [2000/3236], Loss: 2.1385, Perplexity: 8.48640
# Epoch [9/10], Step [2100/3236], Loss: 1.7090, Perplexity: 5.52368
# Epoch [9/10], Step [2200/3236], Loss: 1.7375, Perplexity: 5.68347
# Epoch [9/10], Step [2300/3236], Loss: 1.7233, Perplexity: 5.60329
# Epoch [9/10], Step [2400/3236], Loss: 1.6097, Perplexity: 5.00119
# Epoch [9/10], Step [2500/3236], Loss: 1.9000, Perplexity: 6.68595
# Epoch [9/10], Step [2600/3236], Loss: 1.8133, Perplexity: 6.13047
# Epoch [9/10], Step [2700/3236], Loss: 2.6106, Perplexity: 13.6068
# Epoch [9/10], Step [2800/3236], Loss: 1.7647, Perplexity: 5.84015
# Epoch [9/10], Step [2900/3236], Loss: 2.1538, Perplexity: 8.61755
# Epoch [9/10], Step [3000/3236], Loss: 1.7488, Perplexity: 5.74792
# Epoch [9/10], Step [3100/3236], Loss: 1.8546, Perplexity: 6.38890
# Epoch [9/10], Step [3200/3236], Loss: 2.3298, Perplexity: 10.2758
# Epoch [10/10], Step [100/3236], Loss: 1.8337, Perplexity: 6.25709
# Epoch [10/10], Step [200/3236], Loss: 1.7974, Perplexity: 6.03386
# Epoch [10/10], Step [300/3236], Loss: 1.8051, Perplexity: 6.08095
# Epoch [10/10], Step [400/3236], Loss: 2.7314, Perplexity: 15.3546
# Epoch [10/10], Step [500/3236], Loss: 1.8715, Perplexity: 6.49812
# Epoch [10/10], Step [600/3236], Loss: 1.8604, Perplexity: 6.42669
# Epoch [10/10], Step [700/3236], Loss: 1.7159, Perplexity: 5.56186
# Epoch [10/10], Step [800/3236], Loss: 1.9133, Perplexity: 6.77524
# Epoch [10/10], Step [900/3236], Loss: 1.8727, Perplexity: 6.50578
# Epoch [10/10], Step [1000/3236], Loss: 2.0369, Perplexity: 7.6664
# Epoch [10/10], Step [1100/3236], Loss: 1.7828, Perplexity: 5.94650
# Epoch [10/10], Step [1200/3236], Loss: 1.7518, Perplexity: 5.76518
# Epoch [10/10], Step [1300/3236], Loss: 1.7614, Perplexity: 5.82072
# Epoch [10/10], Step [1400/3236], Loss: 2.0041, Perplexity: 7.41914
# Epoch [10/10], Step [1500/3236], Loss: 1.8507, Perplexity: 6.36469
# Epoch [10/10], Step [1600/3236], Loss: 1.8197, Perplexity: 6.16995
# Epoch [10/10], Step [1700/3236], Loss: 1.7866, Perplexity: 5.96907
# Epoch [10/10], Step [1800/3236], Loss: 1.7626, Perplexity: 5.82755
# Epoch [10/10], Step [1900/3236], Loss: 1.7469, Perplexity: 5.73674
# Epoch [10/10], Step [2000/3236], Loss: 1.8400, Perplexity: 6.29652
# Epoch [10/10], Step [2100/3236], Loss: 1.8163, Perplexity: 6.14903
# Epoch [10/10], Step [2200/3236], Loss: 1.8905, Perplexity: 6.62297
# Epoch [10/10], Step [2300/3236], Loss: 1.9492, Perplexity: 7.02320
# Epoch [10/10], Step [2400/3236], Loss: 1.8760, Perplexity: 6.52736
# Epoch [10/10], Step [2500/3236], Loss: 1.7364, Perplexity: 5.67680
# Epoch [10/10], Step [2600/3236], Loss: 2.3377, Perplexity: 10.3570
# Epoch [10/10], Step [2700/3236], Loss: 2.1222, Perplexity: 8.34939
# Epoch [10/10], Step [2800/3236], Loss: 1.8893, Perplexity: 6.61472
# Epoch [10/10], Step [2900/3236], Loss: 2.0526, Perplexity: 7.78794
# Epoch [10/10], Step [3000/3236], Loss: 2.6512, Perplexity: 14.1715
# Epoch [10/10], Step [3100/3236], Loss: 2.0215, Perplexity: 7.54930
# Epoch [10/10], Step [3200/3236], Loss: 1.9256, Perplexity: 6.85958
# Epoch [10/10], Step [3236/3236], Loss: 2.1384, Perplexity: 8.48621

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
